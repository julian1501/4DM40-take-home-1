# %%
# Read the file and parse the events
filename = "C:/Users/20212127/Documents/Y4_Q4/4DM40/data/EPTdata-ExerciseSetLefeber1-Ex4.txt"

# Load data
events = []
with open(filename, 'r') as f:
    for line in f:
        parts = line.strip().split('\t')
        time = int(parts[0])
        lot = parts[1]
        event_type = parts[2]
        # Extract lot number from lot name
        lot_number = int(lot.replace('lot', ''))
        events.append((time, event_type, lot_number))

# EPT Algorithm

def detOvert(xs, i):
    ys = []
    new_xs = []
    found = False
    for (j, aw) in xs:
        if not found:
            if j < i:
                ys.append((j, aw))
            elif j == i:
                found = True
                continue
        else:
            new_xs.append((j, aw))
    return ys + new_xs, len(ys), aw

xs = []  # list of (arrival_number, aw)
s = None  # EPT start time
sw = None  # WIP-level after EPT start

# Outputs
EPT_results = []  # (EPT_duration, WIP-level)
Overtaking_results = []  # (number_overtaken, aw)

for (tau, ev, i) in events:
    if ev == 'A':
        if len(xs) == 0:
            s, sw = tau, 1
        xs.append((i, len(xs)))
    elif ev == 'D':
        # End current EPT
        EPT_duration = tau - s
        EPT_results.append((EPT_duration, sw))
        
        xs, k, aw = detOvert(xs, i)
        Overtaking_results.append((k, aw))

        if len(xs) > 0:
            s, sw = tau, len(xs)

# Display Results
print("EPT Durations and WIP-levels:")
for duration, wip in EPT_results:
    print(f"EPT Duration: {duration}, WIP-level: {wip}")

print("\nOvertaking Details:")
for overtaken, aw in Overtaking_results:
    print(f"Number of overtaken lots: {overtaken}, WIP before arrival: {aw}")

# Calculate and display mean EPT duration
mean_EPT = sum(duration for duration, _ in EPT_results) / len(EPT_results)
print(f"\nMean EPT Duration: {mean_EPT:.2f}")
# Out:
# EPT Durations and WIP-levels:
# EPT Duration: 26, WIP-level: 1
# EPT Duration: 40, WIP-level: 1
# EPT Duration: 65, WIP-level: 1
# EPT Duration: 46, WIP-level: 1
# EPT Duration: 48, WIP-level: 1
# EPT Duration: 54, WIP-level: 2
# EPT Duration: 129, WIP-level: 1
# EPT Duration: 16, WIP-level: 2
# EPT Duration: 4, WIP-level: 1
# EPT Duration: 101, WIP-level: 1
# EPT Duration: 41, WIP-level: 1
# EPT Duration: 120, WIP-level: 1
# EPT Duration: 58, WIP-level: 1
# EPT Duration: 137, WIP-level: 1
# EPT Duration: 68, WIP-level: 2
# EPT Duration: 41, WIP-level: 2
# EPT Duration: 51, WIP-level: 2
# EPT Duration: 11, WIP-level: 2
# EPT Duration: 8, WIP-level: 1
# EPT Duration: 150, WIP-level: 1
# EPT Duration: 57, WIP-level: 3
# EPT Duration: 15, WIP-level: 3
# EPT Duration: 39, WIP-level: 2
# EPT Duration: 222, WIP-level: 1
# EPT Duration: 31, WIP-level: 2
# EPT Duration: 99, WIP-level: 1
# EPT Duration: 79, WIP-level: 3
# EPT Duration: 22, WIP-level: 3
# EPT Duration: 30, WIP-level: 3
# EPT Duration: 104, WIP-level: 2
# EPT Duration: 239, WIP-level: 1
# EPT Duration: 43, WIP-level: 4
# EPT Duration: 38, WIP-level: 4
# EPT Duration: 11, WIP-level: 4
# EPT Duration: 23, WIP-level: 3
# EPT Duration: 79, WIP-level: 3
# EPT Duration: 7, WIP-level: 5
# EPT Duration: 33, WIP-level: 4
# EPT Duration: 38, WIP-level: 3
# EPT Duration: 6, WIP-level: 3
# EPT Duration: 225, WIP-level: 2
# EPT Duration: 98, WIP-level: 2
# EPT Duration: 163, WIP-level: 2
# EPT Duration: 218, WIP-level: 2
# EPT Duration: 16, WIP-level: 2
# EPT Duration: 264, WIP-level: 1
# EPT Duration: 121, WIP-level: 1
# EPT Duration: 74, WIP-level: 2
# EPT Duration: 29, WIP-level: 2
# EPT Duration: 23, WIP-level: 1
# EPT Duration: 88, WIP-level: 1
# EPT Duration: 59, WIP-level: 1
# EPT Duration: 50, WIP-level: 1
# EPT Duration: 89, WIP-level: 2
# EPT Duration: 44, WIP-level: 4
# EPT Duration: 5, WIP-level: 3
# EPT Duration: 165, WIP-level: 2
# EPT Duration: 11, WIP-level: 3
# EPT Duration: 78, WIP-level: 2
# EPT Duration: 86, WIP-level: 2
#
# Overtaking Details:
# Number of overtaken lots: 0, WIP before arrival: 0
# Number of overtaken lots: 0, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 0
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 2, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 0
# Number of overtaken lots: 0, WIP before arrival: 0
# Number of overtaken lots: 1, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 0
# Number of overtaken lots: 1, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 3
# Number of overtaken lots: 2, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 3
# Number of overtaken lots: 2, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 1
# Number of overtaken lots: 2, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 3
# Number of overtaken lots: 1, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 3
# Number of overtaken lots: 1, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 4
# Number of overtaken lots: 2, WIP before arrival: 4
# Number of overtaken lots: 1, WIP before arrival: 4
# Number of overtaken lots: 2, WIP before arrival: 4
# Number of overtaken lots: 2, WIP before arrival: 3
# Number of overtaken lots: 2, WIP before arrival: 5
# Number of overtaken lots: 0, WIP before arrival: 5
# Number of overtaken lots: 0, WIP before arrival: 5
# Number of overtaken lots: 1, WIP before arrival: 3
# Number of overtaken lots: 2, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 1
# Number of overtaken lots: 0, WIP before arrival: 1
# Number of overtaken lots: 1, WIP before arrival: 1
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 4
# Number of overtaken lots: 0, WIP before arrival: 4
# Number of overtaken lots: 2, WIP before arrival: 4
# Number of overtaken lots: 1, WIP before arrival: 3
# Number of overtaken lots: 0, WIP before arrival: 3
# Number of overtaken lots: 1, WIP before arrival: 2
# Number of overtaken lots: 0, WIP before arrival: 2
#
# Mean EPT Duration: 72.25
